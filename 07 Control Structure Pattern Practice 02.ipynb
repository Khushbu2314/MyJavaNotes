// %%
int n = 5;

// %%
//1

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (lastElement%2!=0) ? (char)('A'+lastElement-1) : (char)('a'+lastElement-1)
        );
    }
    System.out.println();
}
// Out:
// A
// bb
// CCC
// dddd
// EEEEE
// dddd
// CCC
// bb
// A

// %%
//2

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (lastElement%2!=0) ? (char)('A'-lastElement+n) : (char)('a'-lastElement+n)
        );
    }
    System.out.println();
}
// Out:
// E
// dd
// CCC
// bbbb
// AAAAA
// bbbb
// CCC
// dd
// E

// %%
//3

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (j%2!=0) ? (char)('A'+j-1) : (char)('a'+j-1)
        );
    }
    System.out.println();
}
// Out:
// A
// Ab
// AbC
// AbCd
// AbCdE
// AbCd
// AbC
// Ab
// A

// %%
//4

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = lastElement; j>=1; j--){
        System.out.print(
            (j%2!=0) ? (char)('A'+j-1) : (char)('a'+j-1)
        );
    }
    System.out.println();
}
// Out:
// A
// bA
// CbA
// dCbA
// EdCbA
// dCbA
// CbA
// bA
// A

// %%
//5

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (j%2!=0) ? (char)('A'-j+n) : (char)('a'-j+n)
        );
    }
    System.out.println();
}
// Out:
// E
// Ed
// EdC
// EdCb
// EdCbA
// EdCb
// EdC
// Ed
// E

// %%
//6

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = lastElement; j>=1; j--){
        System.out.print(
            (j%2!=0) ? (char)('A'-j+n) : (char)('a'-j+n)
        );
    }
    System.out.println();
}
// Out:
// E
// dE
// CdE
// bCdE
// AbCdE
// bCdE
// CdE
// dE
// E

// %%
//7

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (j%2!=0) ? (char)('A'+i-1) : (char)('a'+i-1)
        );
    }
    System.out.println();
}
// Out:
// A
// Bb
// CcC
// DdDd
// EeEeE
// FfFf
// GgG
// Hh
// I

// %%
//8

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = lastElement; j>=1; j--){
        System.out.print(
            (j%2!=0) ? (char)('A'-lastElement+n) : (char)('a'-lastElement+n)
        );
    }
    System.out.println();
}
// Out:
// E
// dD
// CcC
// bBbB
// AaAaA
// bBbB
// CcC
// dD
// E

// %%
//9

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (i%2!=0) ? (char)('A'+j-1) : (char)('a'+j-1)
        );
    }
    System.out.println();
}
// Out:
// A
// ab
// ABC
// abcd
// ABCDE
// abcd
// ABC
// ab
// A

// %%
//10

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = lastElement; j>=1; j--){
        System.out.print(
            (i%2!=0) ? (char)('A'+j-1) : (char)('a'+j-1)
        );
    }
    System.out.println();
}
// Out:
// A
// ba
// CBA
// dcba
// EDCBA
// dcba
// CBA
// ba
// A

// %%
//11

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = 1; j<=lastElement; j++){
        System.out.print(
            (i%2!=0) ? (char)('A'-j+n) : (char)('a'-j+n)
        );
    }
    System.out.println();
}
// Out:
// E
// ed
// EDC
// edcb
// EDCBA
// edcb
// EDC
// ed
// E

// %%
//12

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;
    for(int j = lastElement; j>=1; j--){
        System.out.print(
            (i%2!=0) ? (char)('A'-j+n) : (char)('a'-j+n)
        );
    }
    System.out.println();
}
// Out:
// E
// de
// CDE
// bcde
// ABCDE
// bcde
// CDE
// de
// E

// %%
//13

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? n-i+1 : i-n+1;

    for(int j = 1; j<=lastElement; j++){
        System.out.print((char)
          ((i%2!=0)? 'A'+lastElement-1 : 'a'+lastElement-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EEEEE
// dddd
// CCC
// bb
// A
// bb
// CCC
// dddd
// EEEEE

// %%
//14

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = lastElement; j<=n; j++){
        System.out.print((char)
          ((i%2!=0)? 'A'+lastElement-1 : 'a'+lastElement-1  )
        );
    }
    
    System.out.println();
}
// Out:
// AAAAA
// bbbb
// CCC
// dd
// E
// dd
// CCC
// bbbb
// AAAAA

// %%
//15

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = 1; j<=n-lastElement+1; j++){
        System.out.print((char)
          ((j%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// AbCdE
// AbCd
// AbC
// Ab
// A
// Ab
// AbC
// AbCd
// AbCdE

// %%
//16

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? n-i+1 : i-n+1;

    for(int j = lastElement; j>=1; j--){
        System.out.print((char)
          ((j%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EdCbA
// dCbA
// CbA
// bA
// A
// bA
// CbA
// dCbA
// EdCbA

// %%
//17

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = n; j>=lastElement; j--){
        System.out.print((char)
          ((j%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EdCbA
// EdCb
// EdC
// Ed
// E
// Ed
// EdC
// EdCb
// EdCbA

// %%
//18

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = lastElement; j<=n; j++){
        System.out.print((char)
          ((j%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// AbCdE
// bCdE
// CdE
// dE
// E
// dE
// CdE
// bCdE
// AbCdE

// %%
//19

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? n-i+1 : i-n+1;

    for(int j = 1; j<=lastElement; j++){
        System.out.print((char)
          ((j%2!=0)? 'A'+lastElement-1 : 'a'+lastElement-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EeEeE
// DdDd
// CcC
// Bb
// A
// Bb
// CcC
// DdDd
// EeEeE

// %%
//20

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = n-lastElement+1; j>=1; j--){
        System.out.print((char)
          ((j%2!=0)? 'A'+lastElement-1 : 'a'+lastElement-1  )
        );
    }
    
    System.out.println();
}
// Out:
// AaAaA
// bBbB
// CcC
// dD
// E
// dD
// CcC
// bBbB
// AaAaA

// %%
//21

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? n-i+1 : i-n+1;

    for(int j = 1; j<=lastElement; j++){
        System.out.print((char)
          ((i%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// ABCDE
// abcd
// ABC
// ab
// A
// ab
// ABC
// abcd
// ABCDE

// %%
//22

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? n-i+1 : i-n+1;

    for(int j = lastElement; j>=1; j--){
        System.out.print((char)
          ((i%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EDCBA
// dcba
// CBA
// ba
// A
// ba
// CBA
// dcba
// EDCBA

// %%
//23 //working

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = n; j>=lastElement; j--){
        System.out.print((char)
          ((i%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// EDCBA
// edcb
// EDC
// ed
// E
// ed
// EDC
// edcb
// EDCBA

// %%
//24

for(int i = 1; i<=n*2-1; i++){
    int lastElement = (i<=n)? i : n*2-i;

    for(int j = lastElement; j<=n; j++){
        System.out.print((char)
          ((i%2!=0)? 'A'+j-1 : 'a'+j-1  )
        );
    }
    
    System.out.println();
}
// Out:
// ABCDE
// bcde
// CDE
// de
// E
// de
// CDE
// bcde
// ABCDE
